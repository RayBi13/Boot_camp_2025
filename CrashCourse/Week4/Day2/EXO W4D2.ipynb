# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import mean_squared_error

# %%
np.random.seed(0)
x = np.arange(-1, 1, 0.1)  # Crée 20 points entre -1 et 1 (pas de 0.1)
y = -x**2 + np.random.normal(0, 0.05, len(x))  # y = -x^2 + bruit gaussien

# %%
plt.figure(figsize=(6, 6))
plt.scatter(x, y, color='blue', edgecolor='k')
plt.title("Dataset avec Bruit (y = -x^2)")
plt.xlabel("x")
plt.ylabel("y")
plt.show()

# %%
x_train = x[:12]
y_train = y[:12]
x_test = x[12:]
y_test = y[12:]

# %%
test_loss, test_accuracy = model_improved.evaluate(X_test, y_test, verbose=0)
print("Test Loss:", test_loss)
print("Test Accuracy:", test_accuracy)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-d830f9fd19e5> in <cell line: 0>()
# ----> 1 test_loss, test_accuracy = model_improved.evaluate(X_test, y_test, verbose=0)
#       2 print("Test Loss:", test_loss)
#       3 print("Test Accuracy:", test_accuracy)
#
# NameError: name 'model_improved' is not defined
