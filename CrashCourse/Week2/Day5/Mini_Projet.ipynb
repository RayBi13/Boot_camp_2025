# %%
import seaborn as sns
import matplotlib.pyplot as plt
import pandas as pd

# # df = pd.read_excel("your_file.xlsx", engine="openpyxl")
# # csv_file = "US Superstore data.csv"
# # df.to_csv(csv_file, index=False)
# # print(f"Excel file converted to CSV: {csv_file}")

# # ----------------
# excel_url = 'C:\Users\bintu\Downloads\PSTB DATA'

# # Download the Excel file and load it into a DataFrame
# df = pd.read_excel(excel_url)

# # Display the first few rows of the DataFrame
# print("Excel Data:")
# print(df.head())

# csv_file_path = 'US Superstore data.csv'

# # Convert the DataFrame to a CSV file
# df.to_csv(csv_file_path, index=False)

# %%
# !pip install xlrd
# Out:
# ...
# [notice] A new release of pip is available: 24.3.1 -> 25.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
file_path = "US Superstore data.xls"
df = pd.read_excel(file_path)

# %%
fichier_en_CSV = "US Superstore data.xls"
df.to_csv (fichier_en_CSV, index=False, encoding="utf-8")

# %%
df.head()
# Out:
#    Row ID        Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 1       2  CA-2016-152156 2016-11-08 2016-11-11    Second Class    CG-12520
# 2       3  CA-2016-138688 2016-06-12 2016-06-16    Second Class    DV-13045
# 3       4  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
# 4       5  US-2015-108966 2015-10-11 2015-10-18  Standard Class    SO-20335
#
#      Customer Name    Segment        Country             City  ...  \
# 0      Claire Gute   Consumer  United States        Henderson  ...
# 1      Claire Gute   Consumer  United States        Henderson  ...
# 2  Darrin Van Huff  Corporate  United States      Los Angeles  ...
# 3   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
# 4   Sean O'Donnell   Consumer  United States  Fort Lauderdale  ...
#
#   Postal Code  Region       Product ID         Category Sub-Category  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9994 entries, 0 to 9993
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         9994 non-null   int64
#  1   Order ID       9994 non-null   object
#  2   Order Date     9994 non-null   datetime64[ns]
#  3   Ship Date      9994 non-null   datetime64[ns]
#  4   Ship Mode      9994 non-null   object
#  5   Customer ID    9994 non-null   object
#  6   Customer Name  9994 non-null   object
#  7   Segment        9994 non-null   object
#  8   Country        9994 non-null   object
#  9   City           9994 non-null   object
#  10  State          9994 non-null   object
#  11  Postal Code    9994 non-null   int64
#  12  Region         9994 non-null   object
#  13  Product ID     9994 non-null   object
#  14  Category       9994 non-null   object
#  15  Sub-Category   9994 non-null   object
#  16  Product Name   9994 non-null   object
# ...

# %%
df.describe()
# Out:
#             Row ID                     Order Date  \
# count  9994.000000                           9994
# mean   4997.500000  2016-04-30 00:07:12.259355648
# min       1.000000            2014-01-03 00:00:00
# 25%    2499.250000            2015-05-23 00:00:00
# 50%    4997.500000            2016-06-26 00:00:00
# 75%    7495.750000            2017-05-14 00:00:00
# max    9994.000000            2017-12-30 00:00:00
# std    2885.163629                            NaN
#
#                            Ship Date   Postal Code         Sales     Quantity  \
# count                           9994   9994.000000   9994.000000  9994.000000
# mean   2016-05-03 23:06:58.571142912  55190.379428    229.858001     3.789574
# min              2014-01-07 00:00:00   1040.000000      0.444000     1.000000
# 25%              2015-05-27 00:00:00  23223.000000     17.280000     2.000000
# 50%              2016-06-29 00:00:00  56430.500000     54.490000     3.000000
# ...

# %%
# Je vvérifie qu'il n'y a rien de manquant
df.isnull().sum()
# Out:
# Row ID           0
# Order ID         0
# Order Date       0
# Ship Date        0
# Ship Mode        0
# Customer ID      0
# Customer Name    0
# Segment          0
# Country          0
# City             0
# State            0
# Postal Code      0
# Region           0
# Product ID       0
# Category         0
# Sub-Category     0
# Product Name     0
# Sales            0
# Quantity         0
# Discount         0
# Profit           0
# dtype: int64

# %%
ventes_par_etat = df.groupby('State')['Sales'].sum().reset_index()
ventes_par_etat.head()
# Out:
#         State        Sales
# 0     Alabama   19510.6400
# 1     Arizona   35282.0010
# 2    Arkansas   11678.1300
# 3  California  457687.6315
# 4    Colorado   32108.1180

# %%
# Visualisation Schématique de mon atten
plt.figure(figsize=(12, 6))
plt.bar(ventes_par_etat['State'], ventes_par_etat['Sales'], color='skyblue')
plt.xlabel('État')
plt.ylabel('Ventes')
plt.title('Ventes par État')
plt.xticks(rotation=90)  # Rotation des noms des États pour une meilleure lisibilité
plt.show()

# %%
# Filtrage dees données pour New York et la Californie
ny_data = df[df['State'] == 'New York']
ca_data = df[df['State'] == 'Californie']

# Calcul des ventes et bénéfices pour chaque État
ny_ventes_total = ny_data['Sales'].sum()
ca_ventes_total = ca_data['Sales'].sum()

ny_benefices_total = ny_data['Profit'].sum()  
ca_benefices_total = ca_data['Profit'].sum()

# %%
# Calcule  de la différence
difference_ventes = ny_ventes_total - ca_ventes_total
difference_benefices = ny_benefices_total - ca_benefices_total

# Le résultats
print(f"Différence des ventes entre New York et la Californie: {difference_ventes}")
print(f"Différence des bénéfices entre New York et la Californie: {difference_benefices}")
# Out:
# Différence des ventes entre New York et la Californie: 310876.27099999995
# Différence des bénéfices entre New York et la Californie: 74038.54859999998

# %%
# Ici on cherche le meilleur client (en termes de ventes ;) 
meilleur_client_ventes = df.groupby('client')['ventes'].sum().idxmax()
